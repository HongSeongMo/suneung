# %% [markdown]
# <a href="https://colab.research.google.com/github/HongSeongMo/suneung/blob/main/suneung_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('suneung')
# Out:
# suneung

# %%
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/suneung_test_num.csv')
df.head()
# Out:
#    year  resister_num  test_num  ratio
# 0  1994        742668    716326   96.5
# 1  1994        750181    726634   96.9
# 2  1995        781749    757488   96.9
# 3  1996        840661    809867   96.3
# 4  1997        824374    795338   96.5

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   year          32 non-null     int64
#  1   resister_num  32 non-null     int64
#  2   test_num      32 non-null     int64
#  3   ratio         32 non-null     float64
# dtypes: float64(1), int64(3)
# memory usage: 1.1 KB

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# 필요 라이브러리 불러오기
import matplotlib.font_manager as fm
import os
import matplotlib.pyplot as plt

# apt-get : 패키지 설치 명령어
# -qq : 에러외의 메세지 숨기는 옵션키
# !apt-get -qq install fonts-nanum


fe = fm.FontEntry(
    fname=r'/usr/share/fonts/truetype/nanum/NanumGothic.ttf', # ttf 파일이 저장되어 있는 경로
    name='NanumGothic')                        # 이 폰트의 원하는 이름 설정
fm.fontManager.ttflist.insert(0, fe)              # Matplotlib에 폰트 추가
plt.rcParams.update({'font.size': 18, 'font.family': 'NanumGothic'}) # 폰트 설정

# %%
plt.figure(figsize=(20, 10))  # 시각화 영역의 크기를 설정
plt.plot(df['year'], df['test_num'], color='red', label='응시자수')
plt.plot(df['year'], df['resister_num'], color='blue', label = '접수자수')
plt.title('연도별 응시자수')  # 그래프 제목 설정
plt.xlabel('년도')  # x축 레이블 설정
plt.ylabel('응시자수')  # y축 레이블 설정
plt.legend()  # 범례 표시
plt.show()
